# %%
# !cd /content/

# %%
# !unzip pytorch-YOLOv4
# Out:
# Archive:  pytorch-YOLOv4.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of pytorch-YOLOv4 or
#         pytorch-YOLOv4.zip, and cannot find pytorch-YOLOv4.ZIP, period.

# %%
# !ls
# Out:
# pytorch-YOLOv4.zip  sample_data

# %%
# !unzip ./pytorch-YOLOv4.zip
# Out:
# Archive:  ./pytorch-YOLOv4.zip
#   inflating: pytorch-YOLOv4/.gitignore
#   inflating: pytorch-YOLOv4/cfg.py
#    creating: pytorch-YOLOv4/cfg/
#   inflating: pytorch-YOLOv4/cfg/custom-yolov4-detector.cfg
#   inflating: pytorch-YOLOv4/cfg/yolov3.cfg
#   inflating: pytorch-YOLOv4/cfg/yolov3-tiny.cfg
#   inflating: pytorch-YOLOv4/cfg/yolov4.cfg
#   inflating: pytorch-YOLOv4/cfg/yolov4-custom.cfg
#   inflating: pytorch-YOLOv4/cfg/yolov4-tiny.cfg
#    creating: pytorch-YOLOv4/data/
#   inflating: pytorch-YOLOv4/data/coco.names
#   inflating: pytorch-YOLOv4/data/dog.jpg
#   inflating: pytorch-YOLOv4/data/giraffe.jpg
#   inflating: pytorch-YOLOv4/data/prediction.jpg
#   inflating: pytorch-YOLOv4/data/voc.names
#  extracting: pytorch-YOLOv4/data/x.names
#   inflating: pytorch-YOLOv4/dataset.py
#   inflating: pytorch-YOLOv4/demo.py
#   inflating: pytorch-YOLOv4/demo_darknet2onnx.py
#   inflating: pytorch-YOLOv4/demo_pytorch2onnx.py
#   inflating: pytorch-YOLOv4/demo_tensorflow.py
#   inflating: pytorch-YOLOv4/demo_trt.py
#   inflating: pytorch-YOLOv4/evaluate_on_coco.py
#   inflating: pytorch-YOLOv4/License.txt
#   inflating: pytorch-YOLOv4/models.py
#   inflating: pytorch-YOLOv4/README.md
#   inflating: pytorch-YOLOv4/requirements.txt
#    creating: pytorch-YOLOv4/tool/
#  extracting: pytorch-YOLOv4/tool/__init__.py
#   inflating: pytorch-YOLOv4/tool/camera.py
#   inflating: pytorch-YOLOv4/tool/coco_annotation.py
#   inflating: pytorch-YOLOv4/tool/config.py
#   inflating: pytorch-YOLOv4/tool/darknet2onnx.py
#   inflating: pytorch-YOLOv4/tool/darknet2pytorch.py
#   inflating: pytorch-YOLOv4/tool/onnx2tensorflow.py
#   inflating: pytorch-YOLOv4/tool/pytorch2onnx.py
#   inflating: pytorch-YOLOv4/tool/region_loss.py
#   inflating: pytorch-YOLOv4/tool/torch_utils.py
#    creating: pytorch-YOLOv4/tool/tv_reference/
#   inflating: pytorch-YOLOv4/tool/tv_reference/coco_eval.py
#   inflating: pytorch-YOLOv4/tool/tv_reference/coco_utils.py
#   inflating: pytorch-YOLOv4/tool/tv_reference/engine.py
#   inflating: pytorch-YOLOv4/tool/tv_reference/group_by_aspect_ratio.py
#   inflating: pytorch-YOLOv4/tool/tv_reference/README.md
#   inflating: pytorch-YOLOv4/tool/tv_reference/train.py
#   inflating: pytorch-YOLOv4/tool/tv_reference/transforms.py
#   inflating: pytorch-YOLOv4/tool/tv_reference/utils.py
#   inflating: pytorch-YOLOv4/tool/utils.py
#   inflating: pytorch-YOLOv4/tool/utils_iou.py
#   inflating: pytorch-YOLOv4/tool/utils_iou_test.py
#   inflating: pytorch-YOLOv4/tool/yolo_layer.py
#   inflating: pytorch-YOLOv4/train.py
#   inflating: pytorch-YOLOv4/Use_yolov4_to_train_your_own_data.md
#    creating: pytorch-YOLOv4/weight/
#   inflating: pytorch-YOLOv4/weight/custom-yolov4-detector_last.weights

# %%
# %cd ./pytorch-YOLOv4/
# Out:
# /content/pytorch-YOLOv4

# %%
# !python demo.py -cfgfile cfg/custom-yolov4-detector.cfg -weightfile weight/custom-yolov4-detector_last.weights -imgfile test/image_0006.jpg
# Out:
# convalution havn't activate linear
# convalution havn't activate linear
# convalution havn't activate linear
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   384 x 512 x   3   ->   384 x 512 x  32
#     1 conv     64  3 x 3 / 2   384 x 512 x  32   ->   192 x 256 x  64
#     2 conv     64  1 x 1 / 1   192 x 256 x  64   ->   192 x 256 x  64
#     3 route  1
#     4 conv     64  1 x 1 / 1   192 x 256 x  64   ->   192 x 256 x  64
#     5 conv     32  1 x 1 / 1   192 x 256 x  64   ->   192 x 256 x  32
#     6 conv     64  3 x 3 / 1   192 x 256 x  32   ->   192 x 256 x  64
#     7 shortcut 4
#     8 conv     64  1 x 1 / 1   192 x 256 x  64   ->   192 x 256 x  64
#     9 route  8 2
#    10 conv     64  1 x 1 / 1   192 x 256 x 128   ->   192 x 256 x  64
#    11 conv    128  3 x 3 / 2   192 x 256 x  64   ->    96 x 128 x 128
#    12 conv     64  1 x 1 / 1    96 x 128 x 128   ->    96 x 128 x  64
#    13 route  11
#    14 conv     64  1 x 1 / 1    96 x 128 x 128   ->    96 x 128 x  64
#    15 conv     64  1 x 1 / 1    96 x 128 x  64   ->    96 x 128 x  64
#    16 conv     64  3 x 3 / 1    96 x 128 x  64   ->    96 x 128 x  64
#    17 shortcut 14
#    18 conv     64  1 x 1 / 1    96 x 128 x  64   ->    96 x 128 x  64
#    19 conv     64  3 x 3 / 1    96 x 128 x  64   ->    96 x 128 x  64
#    20 shortcut 17
#    21 conv     64  1 x 1 / 1    96 x 128 x  64   ->    96 x 128 x  64
#    22 route  21 12
#    23 conv    128  1 x 1 / 1    96 x 128 x 128   ->    96 x 128 x 128
#    24 conv    256  3 x 3 / 2    96 x 128 x 128   ->    48 x  64 x 256
#    25 conv    128  1 x 1 / 1    48 x  64 x 256   ->    48 x  64 x 128
#    26 route  24
#    27 conv    128  1 x 1 / 1    48 x  64 x 256   ->    48 x  64 x 128
#    28 conv    128  1 x 1 / 1    48 x  64 x 128   ->    48 x  64 x 128
#    29 conv    128  3 x 3 / 1    48 x  64 x 128   ->    48 x  64 x 128
#    30 shortcut 27
#    31 conv    128  1 x 1 / 1    48 x  64 x 128   ->    48 x  64 x 128
#    32 conv    128  3 x 3 / 1    48 x  64 x 128   ->    48 x  64 x 128
#    33 shortcut 30
#    34 conv    128  1 x 1 / 1    48 x  64 x 128   ->    48 x  64 x 128
#    35 conv    128  3 x 3 / 1    48 x  64 x 128   ->    48 x  64 x 128
#    36 shortcut 33
#    37 conv    128  1 x 1 / 1    48 x  64 x 128   ->    48 x  64 x 128
#    38 conv    128  3 x 3 / 1    48 x  64 x 128   ->    48 x  64 x 128
#    39 shortcut 36
#    40 conv    128  1 x 1 / 1    48 x  64 x 128   ->    48 x  64 x 128
#    41 conv    128  3 x 3 / 1    48 x  64 x 128   ->    48 x  64 x 128
#    42 shortcut 39
#    43 conv    128  1 x 1 / 1    48 x  64 x 128   ->    48 x  64 x 128
#    44 conv    128  3 x 3 / 1    48 x  64 x 128   ->    48 x  64 x 128
#    45 shortcut 42
#    46 conv    128  1 x 1 / 1    48 x  64 x 128   ->    48 x  64 x 128
#    47 conv    128  3 x 3 / 1    48 x  64 x 128   ->    48 x  64 x 128
#    48 shortcut 45
#    49 conv    128  1 x 1 / 1    48 x  64 x 128   ->    48 x  64 x 128
#    50 conv    128  3 x 3 / 1    48 x  64 x 128   ->    48 x  64 x 128
#    51 shortcut 48
#    52 conv    128  1 x 1 / 1    48 x  64 x 128   ->    48 x  64 x 128
#    53 route  52 25
#    54 conv    256  1 x 1 / 1    48 x  64 x 256   ->    48 x  64 x 256
#    55 conv    512  3 x 3 / 2    48 x  64 x 256   ->    24 x  32 x 512
#    56 conv    256  1 x 1 / 1    24 x  32 x 512   ->    24 x  32 x 256
#    57 route  55
#    58 conv    256  1 x 1 / 1    24 x  32 x 512   ->    24 x  32 x 256
#    59 conv    256  1 x 1 / 1    24 x  32 x 256   ->    24 x  32 x 256
#    60 conv    256  3 x 3 / 1    24 x  32 x 256   ->    24 x  32 x 256
#    61 shortcut 58
#    62 conv    256  1 x 1 / 1    24 x  32 x 256   ->    24 x  32 x 256
#    63 conv    256  3 x 3 / 1    24 x  32 x 256   ->    24 x  32 x 256
#    64 shortcut 61
#    65 conv    256  1 x 1 / 1    24 x  32 x 256   ->    24 x  32 x 256
#    66 conv    256  3 x 3 / 1    24 x  32 x 256   ->    24 x  32 x 256
#    67 shortcut 64
#    68 conv    256  1 x 1 / 1    24 x  32 x 256   ->    24 x  32 x 256
#    69 conv    256  3 x 3 / 1    24 x  32 x 256   ->    24 x  32 x 256
#    70 shortcut 67
#    71 conv    256  1 x 1 / 1    24 x  32 x 256   ->    24 x  32 x 256
#    72 conv    256  3 x 3 / 1    24 x  32 x 256   ->    24 x  32 x 256
#    73 shortcut 70
#    74 conv    256  1 x 1 / 1    24 x  32 x 256   ->    24 x  32 x 256
#    75 conv    256  3 x 3 / 1    24 x  32 x 256   ->    24 x  32 x 256
#    76 shortcut 73
#    77 conv    256  1 x 1 / 1    24 x  32 x 256   ->    24 x  32 x 256
#    78 conv    256  3 x 3 / 1    24 x  32 x 256   ->    24 x  32 x 256
#    79 shortcut 76
#    80 conv    256  1 x 1 / 1    24 x  32 x 256   ->    24 x  32 x 256
#    81 conv    256  3 x 3 / 1    24 x  32 x 256   ->    24 x  32 x 256
#    82 shortcut 79
#    83 conv    256  1 x 1 / 1    24 x  32 x 256   ->    24 x  32 x 256
#    84 route  83 56
#    85 conv    512  1 x 1 / 1    24 x  32 x 512   ->    24 x  32 x 512
#    86 conv   1024  3 x 3 / 2    24 x  32 x 512   ->    12 x  16 x1024
#    87 conv    512  1 x 1 / 1    12 x  16 x1024   ->    12 x  16 x 512
#    88 route  86
#    89 conv    512  1 x 1 / 1    12 x  16 x1024   ->    12 x  16 x 512
#    90 conv    512  1 x 1 / 1    12 x  16 x 512   ->    12 x  16 x 512
#    91 conv    512  3 x 3 / 1    12 x  16 x 512   ->    12 x  16 x 512
#    92 shortcut 89
#    93 conv    512  1 x 1 / 1    12 x  16 x 512   ->    12 x  16 x 512
#    94 conv    512  3 x 3 / 1    12 x  16 x 512   ->    12 x  16 x 512
#    95 shortcut 92
#    96 conv    512  1 x 1 / 1    12 x  16 x 512   ->    12 x  16 x 512
#    97 conv    512  3 x 3 / 1    12 x  16 x 512   ->    12 x  16 x 512
#    98 shortcut 95
#    99 conv    512  1 x 1 / 1    12 x  16 x 512   ->    12 x  16 x 512
#   100 conv    512  3 x 3 / 1    12 x  16 x 512   ->    12 x  16 x 512
#   101 shortcut 98
#   102 conv    512  1 x 1 / 1    12 x  16 x 512   ->    12 x  16 x 512
#   103 route  102 87
#   104 conv   1024  1 x 1 / 1    12 x  16 x1024   ->    12 x  16 x1024
#   105 conv    512  1 x 1 / 1    12 x  16 x1024   ->    12 x  16 x 512
#   106 conv   1024  3 x 3 / 1    12 x  16 x 512   ->    12 x  16 x1024
#   107 conv    512  1 x 1 / 1    12 x  16 x1024   ->    12 x  16 x 512
#   108 max          5 x 5 / 1    12 x  16 x 512   ->    12 x  16 x 512
#   109 route  107
#   110 max          9 x 9 / 1    12 x  16 x 512   ->    12 x  16 x 512
#   111 route  107
#   112 max          13 x 13 / 1    12 x  16 x 512   ->    12 x  16 x 512
#   113 route  112 110 108 107
#   114 conv    512  1 x 1 / 1    12 x  16 x2048   ->    12 x  16 x 512
#   115 conv   1024  3 x 3 / 1    12 x  16 x 512   ->    12 x  16 x1024
#   116 conv    512  1 x 1 / 1    12 x  16 x1024   ->    12 x  16 x 512
#   117 conv    256  1 x 1 / 1    12 x  16 x 512   ->    12 x  16 x 256
#   118 upsample           * 2    12 x  16 x 256   ->    24 x  32 x 256
#   119 route  85
#   120 conv    256  1 x 1 / 1    24 x  32 x 512   ->    24 x  32 x 256
#   121 route  120 118
#   122 conv    256  1 x 1 / 1    24 x  32 x 512   ->    24 x  32 x 256
#   123 conv    512  3 x 3 / 1    24 x  32 x 256   ->    24 x  32 x 512
#   124 conv    256  1 x 1 / 1    24 x  32 x 512   ->    24 x  32 x 256
#   125 conv    512  3 x 3 / 1    24 x  32 x 256   ->    24 x  32 x 512
#   126 conv    256  1 x 1 / 1    24 x  32 x 512   ->    24 x  32 x 256
#   127 conv    128  1 x 1 / 1    24 x  32 x 256   ->    24 x  32 x 128
#   128 upsample           * 2    24 x  32 x 128   ->    48 x  64 x 128
#   129 route  54
#   130 conv    128  1 x 1 / 1    48 x  64 x 256   ->    48 x  64 x 128
#   131 route  130 128
#   132 conv    128  1 x 1 / 1    48 x  64 x 256   ->    48 x  64 x 128
#   133 conv    256  3 x 3 / 1    48 x  64 x 128   ->    48 x  64 x 256
#   134 conv    128  1 x 1 / 1    48 x  64 x 256   ->    48 x  64 x 128
#   135 conv    256  3 x 3 / 1    48 x  64 x 128   ->    48 x  64 x 256
#   136 conv    128  1 x 1 / 1    48 x  64 x 256   ->    48 x  64 x 128
#   137 conv    256  3 x 3 / 1    48 x  64 x 128   ->    48 x  64 x 256
#   138 conv     39  1 x 1 / 1    48 x  64 x 256   ->    48 x  64 x  39
#   139 detection
#   140 route  136
#   141 conv    256  3 x 3 / 2    48 x  64 x 128   ->    24 x  32 x 256
#   142 route  141 126
#   143 conv    256  1 x 1 / 1    24 x  32 x 512   ->    24 x  32 x 256
#   144 conv    512  3 x 3 / 1    24 x  32 x 256   ->    24 x  32 x 512
#   145 conv    256  1 x 1 / 1    24 x  32 x 512   ->    24 x  32 x 256
#   146 conv    512  3 x 3 / 1    24 x  32 x 256   ->    24 x  32 x 512
#   147 conv    256  1 x 1 / 1    24 x  32 x 512   ->    24 x  32 x 256
#   148 conv    512  3 x 3 / 1    24 x  32 x 256   ->    24 x  32 x 512
#   149 conv     39  1 x 1 / 1    24 x  32 x 512   ->    24 x  32 x  39
#   150 detection
#   151 route  147
#   152 conv    512  3 x 3 / 2    24 x  32 x 256   ->    12 x  16 x 512
#   153 route  152 116
#   154 conv    512  1 x 1 / 1    12 x  16 x1024   ->    12 x  16 x 512
#   155 conv   1024  3 x 3 / 1    12 x  16 x 512   ->    12 x  16 x1024
#   156 conv    512  1 x 1 / 1    12 x  16 x1024   ->    12 x  16 x 512
#   157 conv   1024  3 x 3 / 1    12 x  16 x 512   ->    12 x  16 x1024
#   158 conv    512  1 x 1 / 1    12 x  16 x1024   ->    12 x  16 x 512
#   159 conv   1024  3 x 3 / 1    12 x  16 x 512   ->    12 x  16 x1024
#   160 conv     39  1 x 1 / 1    12 x  16 x1024   ->    12 x  16 x  39
#   161 detection
# Loading weights from weight/custom-yolov4-detector_last.weights... Done!
# -----------------------------------
#            Preprocess : 0.001852
#       Model Inference : 0.114181
# -----------------------------------
# -----------------------------------
#        max and argmax : 0.001425
#                   nms : 0.000286
# Post processing total : 0.001711
# -----------------------------------
# -----------------------------------
#            Preprocess : 0.001702
#       Model Inference : 0.100456
# -----------------------------------
# -----------------------------------
#        max and argmax : 0.001255
#                   nms : 0.000242
# Post processing total : 0.001496
# -----------------------------------
# test/image_0006.jpg: Predicted in 0.106107 seconds.
# 3: 0.999434
# object: 0.998247
# save plot results to predictions.jpg
# <Figure size 1800x1000 with 1 Axes>

# %%
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
imShow('predictions.jpg')
